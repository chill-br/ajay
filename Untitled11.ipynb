# %% [markdown]
# <a href="https://colab.research.google.com/github/chill-br/ajay/blob/main/Untitled11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import zipfile
from PIL import Image
import os
import tensorflow as tf
from tensorflow.keras import models, layers
import cv2
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from tensorflow import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array

# %%
# !kaggle datasets download -d fatemehmehrparvar/lung-disease
# Out:
# Dataset URL: https://www.kaggle.com/datasets/fatemehmehrparvar/lung-disease
# License(s): Attribution 4.0 International (CC BY 4.0)
# Downloading lung-disease.zip to /content
#  83% 29.0M/34.9M [00:00<00:00, 146MB/s]
# 100% 34.9M/34.9M [00:00<00:00, 141MB/s]

# %%
import zipfile
zip_ref = zipfile.ZipFile('/content/lung-disease.zip', 'r')
zip_ref.extractall('/content')
zip_ref.close()

# %%
basepath='/content/Lung X-Ray Image/Lung X-Ray Image'
categories=['Lung_Opacity','Normal','Viral Pneumonia']

# %%
IMG_SIZE=200
BATCH_SIZE=32
Epochs=50

# %%
fig, axes = plt.subplots(3, 5, figsize=(15, 6))
axes = axes.flatten()
index=0
# Iterate over categories
for category in (os.listdir(basepath)):
    if index >= 15:
          break  # Only display 10 images
    categoryfolder = os.path.join(basepath, category)
    images = os.listdir(categoryfolder)
    for j in range(5):
      # Select a random image from the category
      imgname = np.random.choice(images)
      imgpath = os.path.join(categoryfolder, imgname)
      image_pil = Image.open(imgpath)
      resized_image = image_pil.resize((IMG_SIZE,IMG_SIZE))
      #image_arr = cv2.cvtColor(image_arr, cv2.COLOR_BGR2RGB)  # Convert to RGB
      #print( newarr_img.shape)
      axes[index].imshow(resized_image)
      axes[index].set_title(category)
      axes[index].axis('off')
      index += 1

      if index >= 15:
          break  # Only display 10 images

plt.tight_layout()
plt.show()

# %%
df=pd.DataFrame(columns=['img_url','label'])
def create_train_data():
    training_data=[]
      #iterate over categories folder
    for category in os.listdir(basepath):
        categoryfolder=os.path.join(basepath,category)

          #iterate over the images and add it to test list
        for img in os.listdir(categoryfolder):
                imgpath=os.path.join(categoryfolder,img)
                image_arr=cv2.imread(imgpath)
                newarr_img=cv2.resize(image_arr,(IMG_SIZE,IMG_SIZE))
                label=categories.index(category)
                training_data.append([newarr_img,label])
                df.loc[len(df)]=[imgpath,category]
                #plt.imshow(image_arr)



    return training_data
train_data=create_train_data()

# %%
train_data=create_train_data()

# %%
df.head(1500)
# Out:
#                                                 img_url         label
# 0     /content/Lung X-Ray Image/Lung X-Ray Image/Lun...  Lung_Opacity
# 1     /content/Lung X-Ray Image/Lung X-Ray Image/Lun...  Lung_Opacity
# 2     /content/Lung X-Ray Image/Lung X-Ray Image/Lun...  Lung_Opacity
# 3     /content/Lung X-Ray Image/Lung X-Ray Image/Lun...  Lung_Opacity
# 4     /content/Lung X-Ray Image/Lung X-Ray Image/Lun...  Lung_Opacity
# ...                                                 ...           ...
# 1495  /content/Lung X-Ray Image/Lung X-Ray Image/Nor...        Normal
# 1496  /content/Lung X-Ray Image/Lung X-Ray Image/Nor...        Normal
# 1497  /content/Lung X-Ray Image/Lung X-Ray Image/Nor...        Normal
# 1498  /content/Lung X-Ray Image/Lung X-Ray Image/Nor...        Normal
# 1499  /content/Lung X-Ray Image/Lung X-Ray Image/Nor...        Normal
#
# [1500 rows x 2 columns]

# %%
labels_distribution=df['label'].value_counts()
labels_distribution.plot(kind='bar')
# Out:
# <Axes: xlabel='label'>

# %%
train_df,test_df=train_test_split(df,test_size=0.2,random_state=42,stratify=df.label)
test_df,val_df=train_test_split(test_df,test_size=0.1,random_state=42,stratify=test_df.label)

# %%
print(train_df.shape)
print(test_df.shape)
print(val_df.shape)
# Out:
# (5560, 2)
# (1251, 2)
# (139, 2)

# %%
train_datagen = ImageDataGenerator(rescale=1/255.,validation_split=0.2)

test_datagen = ImageDataGenerator(rescale=1/255.)

val_datagen  = ImageDataGenerator(rescale=1/255.)
train_generator = train_datagen.flow_from_dataframe(dataframe= train_df,x_col="img_url",y_col="label",
                                      target_size=(IMG_SIZE,IMG_SIZE),

                                      class_mode="categorical",
                                      batch_size=BATCH_SIZE,

                                     )

val_generator = val_datagen.flow_from_dataframe(dataframe= val_df,x_col="img_url",y_col="label",
                                      target_size=(IMG_SIZE,IMG_SIZE),

                                      class_mode="categorical",
                                      batch_size=BATCH_SIZE,
                                      shuffle=False
                                     )

test_generator = test_datagen.flow_from_dataframe(dataframe= test_df,x_col="img_url",y_col="label",
                                      target_size=(IMG_SIZE,IMG_SIZE),

                                      class_mode="categorical",
                                      batch_size=BATCH_SIZE,
                                      shuffle=False
                                     )
# Out:
# Found 5560 validated image filenames belonging to 3 classes.
# Found 139 validated image filenames belonging to 3 classes.
# Found 1251 validated image filenames belonging to 3 classes.

# %%
resize_scaling = tf.keras.Sequential([
    layers.Resizing(IMG_SIZE, IMG_SIZE),
    layers.Rescaling(1./255)
])

# %%
model=keras.models.Sequential([
    keras.layers.Conv2D(32,kernel_size=(3,3),input_shape=(IMG_SIZE,IMG_SIZE,3),activation='relu'),
    keras.layers.MaxPooling2D((2,2)),
    keras.layers.Conv2D(32,kernel_size=(3,3)),
    keras.layers.MaxPooling2D((2,2)),
    keras.layers.Conv2D(32,kernel_size=(3,3),activation='relu'),
    keras.layers.MaxPooling2D((2,2)),

    keras.layers.Flatten(),

    keras.layers.Dense(128,activation='relu'),

    keras.layers.Dense(3,activation='softmax')


])
model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 198, 198, 32)        │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 99, 99, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 97, 97, 32)          │           9,248 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 48, 48, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 46, 46, 32)          │           9,248 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 23, 23, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 16928)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 128)                 │       2,166,912 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 3)                   │             387 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 2,186,691 (8.34 MB)
#  Trainable params: 2,186,691 (8.34 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
history=model.fit(train_generator,validation_data=val_generator,epochs=Epochs,batch_size=BATCH_SIZE)
# Out:
# Epoch 1/50
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 23s 90ms/step - accuracy: 0.7033 - loss: 0.6658 - val_accuracy: 0.8489 - val_loss: 0.3399
# Epoch 2/50
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 31s 60ms/step - accuracy: 0.8555 - loss: 0.3413 - val_accuracy: 0.8489 - val_loss: 0.2880
# Epoch 3/50
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 10s 56ms/step - accuracy: 0.8937 - loss: 0.2568 - val_accuracy: 0.8777 - val_loss: 0.2484
# Epoch 4/50
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 10s 52ms/step - accuracy: 0.9249 - loss: 0.1896 - val_accuracy: 0.8993 - val_loss: 0.2127
# Epoch 5/50
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 11s 57ms/step - accuracy: 0.9378 - loss: 0.1545 - val_accuracy: 0.8849 - val_loss: 0.2554
# Epoch 6/50
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 9s 51ms/step - accuracy: 0.9523 - loss: 0.1200 - val_accuracy: 0.9065 - val_loss: 0.1965
# Epoch 7/50
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 9s 46ms/step - accuracy: 0.9748 - loss: 0.0684 - val_accuracy: 0.8993 - val_loss: 0.1955
# Epoch 8/50
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 9s 47ms/step - accuracy: 0.9808 - loss: 0.0545 - val_accuracy: 0.9784 - val_loss: 0.0496
# Epoch 9/50
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 9s 50ms/step - accuracy: 0.9922 - loss: 0.0244 - val_accuracy: 0.9209 - val_loss: 0.1600
# Epoch 10/50
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 11s 52ms/step - accuracy: 0.9900 - loss: 0.0357 - val_accuracy: 0.9856 - val_loss: 0.0543
# Epoch 11/50
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 8s 45ms/step - accuracy: 0.9933 - loss: 0.0222 - val_accuracy: 0.9784 - val_loss: 0.0640
# Epoch 12/50
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 9s 52ms/step - accuracy: 0.9939 - loss: 0.0193 - val_accuracy: 0.9496 - val_loss: 0.1974
# Epoch 13/50
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 10s 52ms/step - accuracy: 0.9937 - loss: 0.0219 - val_accuracy: 0.9856 - val_loss: 0.0265
# Epoch 14/50
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 8s 45ms/step - accuracy: 0.9971 - loss: 0.0086 - val_accuracy: 0.9784 - val_loss: 0.0585
# Epoch 15/50
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 9s 51ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 1.0000 - val_loss: 0.0108
# Epoch 16/50
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 9s 51ms/step - accuracy: 1.0000 - loss: 6.5310e-05 - val_accuracy: 1.0000 - val_loss: 0.0076
# Epoch 17/50
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 8s 46ms/step - accuracy: 1.0000 - loss: 4.6335e-05 - val_accuracy: 1.0000 - val_loss: 0.0066
# Epoch 18/50
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 9s 50ms/step - accuracy: 1.0000 - loss: 3.3220e-05 - val_accuracy: 1.0000 - val_loss: 0.0066
# Epoch 19/50
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 10s 50ms/step - accuracy: 1.0000 - loss: 2.8494e-05 - val_accuracy: 1.0000 - val_loss: 0.0061
# Epoch 20/50
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 10s 51ms/step - accuracy: 1.0000 - loss: 2.2410e-05 - val_accuracy: 1.0000 - val_loss: 0.0061
# Epoch 21/50
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 8s 45ms/step - accuracy: 1.0000 - loss: 1.8908e-05 - val_accuracy: 1.0000 - val_loss: 0.0059
# Epoch 22/50
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 9s 51ms/step - accuracy: 1.0000 - loss: 1.5524e-05 - val_accuracy: 1.0000 - val_loss: 0.0058
# Epoch 23/50
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 10s 52ms/step - accuracy: 1.0000 - loss: 1.4915e-05 - val_accuracy: 1.0000 - val_loss: 0.0056
# Epoch 24/50
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 9s 44ms/step - accuracy: 1.0000 - loss: 1.2518e-05 - val_accuracy: 1.0000 - val_loss: 0.0056
# Epoch 25/50
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 10s 44ms/step - accuracy: 1.0000 - loss: 1.2653e-05 - val_accuracy: 1.0000 - val_loss: 0.0054
# Epoch 26/50
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 11s 46ms/step - accuracy: 1.0000 - loss: 9.8724e-06 - val_accuracy: 1.0000 - val_loss: 0.0056
# Epoch 27/50
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 9s 52ms/step - accuracy: 1.0000 - loss: 9.3412e-06 - val_accuracy: 1.0000 - val_loss: 0.0054
# Epoch 28/50
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 8s 46ms/step - accuracy: 1.0000 - loss: 7.9551e-06 - val_accuracy: 1.0000 - val_loss: 0.0053
# Epoch 29/50
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 9s 48ms/step - accuracy: 1.0000 - loss: 6.7799e-06 - val_accuracy: 1.0000 - val_loss: 0.0055
# Epoch 30/50
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 11s 51ms/step - accuracy: 1.0000 - loss: 6.2316e-06 - val_accuracy: 1.0000 - val_loss: 0.0056
# Epoch 31/50
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 11s 53ms/step - accuracy: 1.0000 - loss: 5.9508e-06 - val_accuracy: 1.0000 - val_loss: 0.0054
# Epoch 32/50
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 9s 45ms/step - accuracy: 1.0000 - loss: 5.0302e-06 - val_accuracy: 1.0000 - val_loss: 0.0054
# Epoch 33/50
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 10s 45ms/step - accuracy: 1.0000 - loss: 4.5379e-06 - val_accuracy: 1.0000 - val_loss: 0.0052
# Epoch 34/50
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 9s 51ms/step - accuracy: 1.0000 - loss: 4.0313e-06 - val_accuracy: 1.0000 - val_loss: 0.0055
# Epoch 35/50
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 10s 53ms/step - accuracy: 1.0000 - loss: 3.6481e-06 - val_accuracy: 1.0000 - val_loss: 0.0051
# Epoch 36/50
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 9s 45ms/step - accuracy: 1.0000 - loss: 3.2021e-06 - val_accuracy: 1.0000 - val_loss: 0.0054
# Epoch 37/50
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 10s 45ms/step - accuracy: 1.0000 - loss: 2.9749e-06 - val_accuracy: 1.0000 - val_loss: 0.0050
# Epoch 38/50
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 9s 51ms/step - accuracy: 1.0000 - loss: 2.9208e-06 - val_accuracy: 1.0000 - val_loss: 0.0047
# Epoch 39/50
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 10s 51ms/step - accuracy: 1.0000 - loss: 2.5487e-06 - val_accuracy: 1.0000 - val_loss: 0.0049
# Epoch 40/50
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 8s 44ms/step - accuracy: 1.0000 - loss: 2.2183e-06 - val_accuracy: 1.0000 - val_loss: 0.0050
# Epoch 41/50
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 9s 50ms/step - accuracy: 1.0000 - loss: 1.9178e-06 - val_accuracy: 1.0000 - val_loss: 0.0049
# Epoch 42/50
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 9s 51ms/step - accuracy: 1.0000 - loss: 1.5467e-06 - val_accuracy: 1.0000 - val_loss: 0.0050
# Epoch 43/50
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 8s 44ms/step - accuracy: 1.0000 - loss: 1.4469e-06 - val_accuracy: 1.0000 - val_loss: 0.0050
# Epoch 44/50
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 10s 54ms/step - accuracy: 1.0000 - loss: 1.4495e-06 - val_accuracy: 1.0000 - val_loss: 0.0048
# Epoch 45/50
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 9s 50ms/step - accuracy: 1.0000 - loss: 1.2424e-06 - val_accuracy: 1.0000 - val_loss: 0.0050
# Epoch 46/50
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 10s 47ms/step - accuracy: 1.0000 - loss: 1.1787e-06 - val_accuracy: 1.0000 - val_loss: 0.0045
# Epoch 47/50
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 10s 45ms/step - accuracy: 1.0000 - loss: 1.0533e-06 - val_accuracy: 1.0000 - val_loss: 0.0048
# Epoch 48/50
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 9s 51ms/step - accuracy: 1.0000 - loss: 9.6360e-07 - val_accuracy: 1.0000 - val_loss: 0.0046
# Epoch 49/50
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 9s 51ms/step - accuracy: 1.0000 - loss: 9.0327e-07 - val_accuracy: 1.0000 - val_loss: 0.0045
# Epoch 50/50
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 8s 45ms/step - accuracy: 1.0000 - loss: 8.2582e-07 - val_accuracy: 1.0000 - val_loss: 0.0043

# %%
val,acc=model.evaluate(train_generator)
# Out:
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 9s 53ms/step - accuracy: 1.0000 - loss: 7.5077e-07

# %%
val,acc=model.evaluate(test_generator)
# Out:
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - accuracy: 0.9812 - loss: 0.2774

# %%
true_value=test_generator.classes
pred=model.predict(test_generator)
pred=np.argmax(model.predict(test_generator),axis=1)
pred_class_name=[categories[p] for p in pred]
pred_class_name
# Out:
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step
# ['Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Viral Pneumonia',
#  'Viral Pneumonia',
#  'Viral Pneumonia',
#  'Viral Pneumonia',
#  'Lung_Opacity',
#  'Normal',
#  'Lung_Opacity',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Lung_Opacity',
#  'Normal',
#  'Lung_Opacity',
#  'Lung_Opacity',
#  'Normal',
#  'Lung_Opacity',
#  'Viral Pneumonia',
#  'Viral Pneumonia',
#  'Viral Pneumonia',
#  'Lung_Opacity',
#  'Normal',
#  'Viral Pneumonia',
#  'Viral Pneumonia',
#  'Viral Pneumonia',
#  'Lung_Opacity',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Lung_Opacity',
#  'Lung_Opacity',
#  'Lung_Opacity',
#  'Normal',
#  'Viral Pneumonia',
#  'Normal',
#  'Viral Pneumonia',
#  'Lung_Opacity',
#  'Normal',
#  'Lung_Opacity',
#  'Lung_Opacity',
#  'Normal',
#  'Lung_Opacity',
#  'Lung_Opacity',
#  'Viral Pneumonia',
#  'Normal',
#  'Lung_Opacity',
#  'Viral Pneumonia',
#  'Normal',
#  'Lung_Opacity',
#  'Viral Pneumonia',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Viral Pneumonia',
#  'Viral Pneumonia',
#  'Viral Pneumonia',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Viral Pneumonia',
#  'Viral Pneumonia',
#  'Viral Pneumonia',
#  'Viral Pneumonia',
#  'Viral Pneumonia',
#  'Lung_Opacity',
#  'Viral Pneumonia',
#  'Lung_Opacity',
#  'Viral Pneumonia',
#  'Normal',
#  'Normal',
#  'Lung_Opacity',
#  'Lung_Opacity',
#  'Viral Pneumonia',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Viral Pneumonia',
#  'Normal',
#  'Lung_Opacity',
#  'Viral Pneumonia',
#  'Viral Pneumonia',
#  'Lung_Opacity',
#  'Lung_Opacity',
#  'Normal',
#  'Lung_Opacity',
#  'Viral Pneumonia',
#  'Lung_Opacity',
#  'Lung_Opacity',
#  'Lung_Opacity',
#  'Viral Pneumonia',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Viral Pneumonia',
#  'Lung_Opacity',
#  'Viral Pneumonia',
#  'Normal',
#  'Viral Pneumonia',
#  'Lung_Opacity',
#  'Normal',
#  'Viral Pneumonia',
#  'Lung_Opacity',
#  'Viral Pneumonia',
#  'Normal',
#  'Lung_Opacity',
#  'Normal',
#  'Viral Pneumonia',
#  'Viral Pneumonia',
#  'Normal',
#  'Normal',
#  'Lung_Opacity',
#  'Viral Pneumonia',
#  'Lung_Opacity',
#  'Lung_Opacity',
#  'Lung_Opacity',
#  'Normal',
#  'Lung_Opacity',
#  'Viral Pneumonia',
#  'Lung_Opacity',
#  'Lung_Opacity',
#  'Normal',
#  'Viral Pneumonia',
#  'Lung_Opacity',
#  'Normal',
#  'Lung_Opacity',
#  'Viral Pneumonia',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Viral Pneumonia',
#  'Normal',
#  'Lung_Opacity',
#  'Viral Pneumonia',
#  'Normal',
#  'Normal',
#  'Viral Pneumonia',
#  'Viral Pneumonia',
#  'Lung_Opacity',
#  'Lung_Opacity',
#  'Normal',
#  'Normal',
#  'Lung_Opacity',
#  'Viral Pneumonia',
#  'Viral Pneumonia',
#  'Lung_Opacity',
#  'Lung_Opacity',
#  'Lung_Opacity',
#  'Lung_Opacity',
#  'Lung_Opacity',
#  'Normal',
#  'Viral Pneumonia',
#  'Lung_Opacity',
#  'Viral Pneumonia',
#  'Viral Pneumonia',
#  'Viral Pneumonia',
#  'Viral Pneumonia',
#  'Lung_Opacity',
#  'Lung_Opacity',
#  'Lung_Opacity',
#  'Lung_Opacity',
#  'Normal',
#  'Normal',
#  'Lung_Opacity',
#  'Viral Pneumonia',
#  'Normal',
#  'Normal',
#  'Viral Pneumonia',
#  'Normal',
#  'Lung_Opacity',
#  'Normal',
#  'Viral Pneumonia',
#  'Normal',
#  'Lung_Opacity',
#  'Normal',
#  'Viral Pneumonia',
#  'Viral Pneumonia',
#  'Normal',
#  'Normal',
#  'Viral Pneumonia',
#  'Lung_Opacity',
#  'Viral Pneumonia',
#  'Normal',
#  'Lung_Opacity',
#  'Normal',
#  'Viral Pneumonia',
#  'Viral Pneumonia',
#  'Lung_Opacity',
#  'Normal',
#  'Normal',
#  'Viral Pneumonia',
#  'Lung_Opacity',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Lung_Opacity',
#  'Viral Pneumonia',
#  'Viral Pneumonia',
#  'Viral Pneumonia',
#  'Viral Pneumonia',
#  'Lung_Opacity',
#  'Lung_Opacity',
#  'Viral Pneumonia',
#  'Normal',
#  'Viral Pneumonia',
#  'Normal',
#  'Normal',
#  'Viral Pneumonia',
#  'Viral Pneumonia',
#  'Normal',
#  'Lung_Opacity',
#  'Normal',
#  'Lung_Opacity',
#  'Viral Pneumonia',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Lung_Opacity',
#  'Lung_Opacity',
#  'Normal',
#  'Lung_Opacity',
#  'Normal',
#  'Lung_Opacity',
#  'Viral Pneumonia',
#  'Lung_Opacity',
#  'Normal',
#  'Viral Pneumonia',
#  'Viral Pneumonia',
#  'Normal',
#  'Lung_Opacity',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Lung_Opacity',
#  'Lung_Opacity',
#  'Normal',
#  'Viral Pneumonia',
#  'Viral Pneumonia',
#  'Lung_Opacity',
#  'Normal',
#  'Viral Pneumonia',
#  'Viral Pneumonia',
#  'Viral Pneumonia',
#  'Normal',
#  'Viral Pneumonia',
#  'Normal',
#  'Normal',
#  'Lung_Opacity',
#  'Normal',
#  'Viral Pneumonia',
#  'Normal',
#  'Normal',
#  'Viral Pneumonia',
#  'Normal',
#  'Normal',
#  'Lung_Opacity',
#  'Viral Pneumonia',
#  'Normal',
#  'Viral Pneumonia',
#  'Viral Pneumonia',
#  'Viral Pneumonia',
#  'Lung_Opacity',
#  'Viral Pneumonia',
#  'Viral Pneumonia',
#  'Normal',
#  'Normal',
#  'Lung_Opacity',
#  'Viral Pneumonia',
#  'Viral Pneumonia',
#  'Viral Pneumonia',
#  'Lung_Opacity',
#  'Lung_Opacity',
#  'Lung_Opacity',
#  'Lung_Opacity',
#  'Lung_Opacity',
#  'Normal',
#  'Normal',
#  'Viral Pneumonia',
#  'Viral Pneumonia',
#  'Viral Pneumonia',
#  'Lung_Opacity',
#  'Lung_Opacity',
#  'Lung_Opacity',
#  'Lung_Opacity',
#  'Viral Pneumonia',
#  'Normal',
#  'Normal',
#  'Lung_Opacity',
#  'Viral Pneumonia',
#  'Normal',
#  'Normal',
#  'Lung_Opacity',
#  'Viral Pneumonia',
#  'Normal',
#  'Viral Pneumonia',
#  'Normal',
#  'Viral Pneumonia',
#  'Lung_Opacity',
#  'Lung_Opacity',
#  'Viral Pneumonia',
#  'Lung_Opacity',
#  'Lung_Opacity',
#  'Normal',
#  'Lung_Opacity',
#  'Lung_Opacity',
#  'Normal',
#  'Viral Pneumonia',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Lung_Opacity',
#  'Viral Pneumonia',
#  'Lung_Opacity',
#  'Viral Pneumonia',
#  'Viral Pneumonia',
#  'Lung_Opacity',
#  'Normal',
#  'Lung_Opacity',
#  'Viral Pneumonia',
#  'Lung_Opacity',
#  'Lung_Opacity',
#  'Lung_Opacity',
#  'Viral Pneumonia',
#  'Lung_Opacity',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Viral Pneumonia',
#  'Viral Pneumonia',
#  'Viral Pneumonia',
#  'Lung_Opacity',
#  'Viral Pneumonia',
#  'Normal',
#  'Lung_Opacity',
#  'Viral Pneumonia',
#  'Lung_Opacity',
#  'Normal',
#  'Viral Pneumonia',
#  'Viral Pneumonia',
#  'Viral Pneumonia',
#  'Normal',
#  'Normal',
#  'Lung_Opacity',
#  'Viral Pneumonia',
#  'Lung_Opacity',
#  'Lung_Opacity',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Lung_Opacity',
#  'Normal',
#  'Viral Pneumonia',
#  'Normal',
#  'Lung_Opacity',
#  'Lung_Opacity',
#  'Viral Pneumonia',
#  'Viral Pneumonia',
#  'Lung_Opacity',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Viral Pneumonia',
#  'Normal',
#  'Viral Pneumonia',
#  'Lung_Opacity',
#  'Lung_Opacity',
#  'Normal',
#  'Viral Pneumonia',
#  'Viral Pneumonia',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Viral Pneumonia',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Lung_Opacity',
#  'Normal',
#  'Lung_Opacity',
#  'Viral Pneumonia',
#  'Normal',
#  'Normal',
#  'Lung_Opacity',
#  'Viral Pneumonia',
#  'Lung_Opacity',
#  'Normal',
#  'Normal',
#  'Lung_Opacity',
#  'Viral Pneumonia',
#  'Normal',
#  'Normal',
#  'Lung_Opacity',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Lung_Opacity',
#  'Lung_Opacity',
#  'Viral Pneumonia',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Lung_Opacity',
#  'Lung_Opacity',
#  'Viral Pneumonia',
#  'Normal',
#  'Viral Pneumonia',
#  'Normal',
#  'Viral Pneumonia',
#  'Lung_Opacity',
#  'Lung_Opacity',
#  'Normal',
#  'Lung_Opacity',
#  'Normal',
#  'Normal',
#  'Viral Pneumonia',
#  'Lung_Opacity',
#  'Normal',
#  'Normal',
#  'Lung_Opacity',
#  'Viral Pneumonia',
#  'Lung_Opacity',
#  'Normal',
#  'Normal',
#  'Lung_Opacity',
#  'Normal',
#  'Lung_Opacity',
#  'Lung_Opacity',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Viral Pneumonia',
#  'Normal',
#  'Lung_Opacity',
#  'Normal',
#  'Lung_Opacity',
#  'Lung_Opacity',
#  'Normal',
#  'Lung_Opacity',
#  'Lung_Opacity',
#  'Normal',
#  'Lung_Opacity',
#  'Lung_Opacity',
#  'Normal',
#  'Lung_Opacity',
#  'Normal',
#  'Viral Pneumonia',
#  'Lung_Opacity',
#  'Viral Pneumonia',
#  'Normal',
#  'Lung_Opacity',
#  'Normal',
#  'Lung_Opacity',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Viral Pneumonia',
#  'Lung_Opacity',
#  'Normal',
#  'Lung_Opacity',
#  'Viral Pneumonia',
#  'Lung_Opacity',
#  'Normal',
#  'Normal',
#  'Viral Pneumonia',
#  'Normal',
#  'Lung_Opacity',
#  'Viral Pneumonia',
#  'Lung_Opacity',
#  'Lung_Opacity',
#  'Viral Pneumonia',
#  'Normal',
#  'Normal',
#  'Viral Pneumonia',
#  'Viral Pneumonia',
#  'Lung_Opacity',
#  'Normal',
#  'Lung_Opacity',
#  'Normal',
#  'Lung_Opacity',
#  'Lung_Opacity',
#  'Normal',
#  'Lung_Opacity',
#  'Viral Pneumonia',
#  'Viral Pneumonia',
#  'Normal',
#  'Normal',
#  'Viral Pneumonia',
#  'Normal',
#  'Viral Pneumonia',
#  'Viral Pneumonia',
#  'Normal',
#  'Normal',
#  'Lung_Opacity',
#  'Viral Pneumonia',
#  'Normal',
#  'Viral Pneumonia',
#  'Viral Pneumonia',
#  'Normal',
#  'Viral Pneumonia',
#  'Normal',
#  'Viral Pneumonia',
#  'Lung_Opacity',
#  'Lung_Opacity',
#  'Viral Pneumonia',
#  'Lung_Opacity',
#  'Viral Pneumonia',
#  'Viral Pneumonia',
#  'Lung_Opacity',
#  'Viral Pneumonia',
#  'Viral Pneumonia',
#  'Normal',
#  'Viral Pneumonia',
#  'Lung_Opacity',
#  'Normal',
#  'Lung_Opacity',
#  'Lung_Opacity',
#  'Viral Pneumonia',
#  'Lung_Opacity',
#  'Viral Pneumonia',
#  'Lung_Opacity',
#  'Lung_Opacity',
#  'Normal',
#  'Normal',
#  'Lung_Opacity',
#  'Normal',
#  'Normal',
#  'Lung_Opacity',
#  'Viral Pneumonia',
#  'Normal',
#  'Normal',
#  'Lung_Opacity',
#  'Lung_Opacity',
#  'Lung_Opacity',
#  'Normal',
#  'Lung_Opacity',
#  'Normal',
#  'Viral Pneumonia',
#  'Normal',
#  'Normal',
#  'Viral Pneumonia',
#  'Lung_Opacity',
#  'Viral Pneumonia',
#  'Normal',
#  'Viral Pneumonia',
#  'Normal',
#  'Lung_Opacity',
#  'Normal',
#  'Normal',
#  'Lung_Opacity',
#  'Normal',
#  'Lung_Opacity',
#  'Viral Pneumonia',
#  'Lung_Opacity',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Lung_Opacity',
#  'Lung_Opacity',
#  'Lung_Opacity',
#  'Lung_Opacity',
#  'Viral Pneumonia',
#  'Viral Pneumonia',
#  'Normal',
#  'Viral Pneumonia',
#  'Lung_Opacity',
#  'Lung_Opacity',
#  'Viral Pneumonia',
#  'Lung_Opacity',
#  'Viral Pneumonia',
#  'Lung_Opacity',
#  'Viral Pneumonia',
#  'Lung_Opacity',
#  'Normal',
#  'Lung_Opacity',
#  'Normal',
#  'Viral Pneumonia',
#  'Normal',
#  'Normal',
#  'Viral Pneumonia',
#  'Lung_Opacity',
#  'Lung_Opacity',
#  'Normal',
#  'Viral Pneumonia',
#  'Viral Pneumonia',
#  'Lung_Opacity',
#  'Viral Pneumonia',
#  'Lung_Opacity',
#  'Viral Pneumonia',
#  'Normal',
#  'Viral Pneumonia',
#  'Viral Pneumonia',
#  'Viral Pneumonia',
#  'Normal',
#  'Viral Pneumonia',
#  'Normal',
#  'Normal',
#  'Viral Pneumonia',
#  'Viral Pneumonia',
#  'Viral Pneumonia',
#  'Viral Pneumonia',
#  'Viral Pneumonia',
#  'Lung_Opacity',
#  'Normal',
#  'Viral Pneumonia',
#  'Normal',
#  'Lung_Opacity',
#  'Normal',
#  'Normal',
#  'Lung_Opacity',
#  'Lung_Opacity',
#  'Lung_Opacity',
#  'Viral Pneumonia',
#  'Viral Pneumonia',
#  'Viral Pneumonia',
#  'Lung_Opacity',
#  'Viral Pneumonia',
#  'Viral Pneumonia',
#  'Viral Pneumonia',
#  'Viral Pneumonia',
#  'Lung_Opacity',
#  'Viral Pneumonia',
#  'Normal',
#  'Viral Pneumonia',
#  'Normal',
#  'Viral Pneumonia',
#  'Lung_Opacity',
#  'Lung_Opacity',
#  'Viral Pneumonia',
#  'Normal',
#  'Normal',
#  'Lung_Opacity',
#  'Normal',
#  'Lung_Opacity',
#  'Lung_Opacity',
#  'Lung_Opacity',
#  'Normal',
#  'Viral Pneumonia',
#  'Lung_Opacity',
#  'Normal',
#  'Lung_Opacity',
#  'Lung_Opacity',
#  'Lung_Opacity',
#  'Viral Pneumonia',
#  'Lung_Opacity',
#  'Normal',
#  'Viral Pneumonia',
#  'Lung_Opacity',
#  'Normal',
#  'Viral Pneumonia',
#  'Lung_Opacity',
#  'Viral Pneumonia',
#  'Lung_Opacity',
#  'Normal',
#  'Viral Pneumonia',
#  'Viral Pneumonia',
#  'Viral Pneumonia',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Viral Pneumonia',
#  'Lung_Opacity',
#  'Viral Pneumonia',
#  'Normal',
#  'Lung_Opacity',
#  'Viral Pneumonia',
#  'Lung_Opacity',
#  'Lung_Opacity',
#  'Normal',
#  'Lung_Opacity',
#  'Viral Pneumonia',
#  'Normal',
#  'Normal',
#  'Viral Pneumonia',
#  'Normal',
#  'Viral Pneumonia',
#  'Lung_Opacity',
#  'Lung_Opacity',
#  'Normal',
#  'Normal',
#  'Viral Pneumonia',
#  'Viral Pneumonia',
#  'Lung_Opacity',
#  'Lung_Opacity',
#  'Viral Pneumonia',
#  'Lung_Opacity',
#  'Normal',
#  'Lung_Opacity',
#  'Lung_Opacity',
#  'Lung_Opacity',
#  'Normal',
#  'Lung_Opacity',
#  'Lung_Opacity',
#  'Viral Pneumonia',
#  'Viral Pneumonia',
#  'Lung_Opacity',
#  'Viral Pneumonia',
#  'Viral Pneumonia',
#  'Lung_Opacity',
#  'Normal',
#  'Viral Pneumonia',
#  'Lung_Opacity',
#  'Viral Pneumonia',
#  'Lung_Opacity',
#  'Viral Pneumonia',
#  'Normal',
#  'Normal',
#  'Viral Pneumonia',
#  'Normal',
#  'Normal',
#  'Lung_Opacity',
#  'Lung_Opacity',
#  'Viral Pneumonia',
#  'Lung_Opacity',
#  'Lung_Opacity',
#  'Lung_Opacity',
#  'Viral Pneumonia',
#  'Normal',
#  'Lung_Opacity',
#  'Normal',
#  'Viral Pneumonia',
#  'Normal',
#  'Viral Pneumonia',
#  'Normal',
#  'Normal',
#  'Viral Pneumonia',
#  'Viral Pneumonia',
#  'Normal',
#  'Viral Pneumonia',
#  'Lung_Opacity',
#  'Normal',
#  'Lung_Opacity',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Lung_Opacity',
#  'Viral Pneumonia',
#  'Normal',
#  'Viral Pneumonia',
#  'Normal',
#  'Normal',
#  'Lung_Opacity',
#  'Normal',
#  'Lung_Opacity',
#  'Normal',
#  'Lung_Opacity',
#  'Lung_Opacity',
#  'Normal',
#  'Viral Pneumonia',
#  'Viral Pneumonia',
#  'Normal',
#  'Viral Pneumonia',
#  'Normal',
#  'Viral Pneumonia',
#  'Normal',
#  'Viral Pneumonia',
#  'Viral Pneumonia',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Viral Pneumonia',
#  'Viral Pneumonia',
#  'Lung_Opacity',
#  'Normal',
#  'Viral Pneumonia',
#  'Viral Pneumonia',
#  'Normal',
#  'Viral Pneumonia',
#  'Lung_Opacity',
#  'Lung_Opacity',
#  'Lung_Opacity',
#  'Normal',
#  'Lung_Opacity',
#  'Viral Pneumonia',
#  'Lung_Opacity',
#  'Lung_Opacity',
#  'Normal',
#  'Lung_Opacity',
#  'Normal',
#  'Viral Pneumonia',
#  'Normal',
#  'Lung_Opacity',
#  'Lung_Opacity',
#  'Lung_Opacity',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Viral Pneumonia',
#  'Lung_Opacity',
#  'Lung_Opacity',
#  'Normal',
#  'Viral Pneumonia',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Viral Pneumonia',
#  'Normal',
#  'Normal',
#  'Lung_Opacity',
#  'Viral Pneumonia',
#  'Lung_Opacity',
#  'Viral Pneumonia',
#  'Normal',
#  'Viral Pneumonia',
#  'Lung_Opacity',
#  'Lung_Opacity',
#  'Lung_Opacity',
#  'Viral Pneumonia',
#  'Normal',
#  'Lung_Opacity',
#  'Normal',
#  'Normal',
#  'Viral Pneumonia',
#  'Lung_Opacity',
#  'Lung_Opacity',
#  'Viral Pneumonia',
#  'Normal',
#  'Viral Pneumonia',
#  'Viral Pneumonia',
#  'Normal',
#  'Viral Pneumonia',
#  'Lung_Opacity',
#  'Normal',
#  'Viral Pneumonia',
#  'Viral Pneumonia',
#  'Viral Pneumonia',
#  'Normal',
#  'Lung_Opacity',
#  'Viral Pneumonia',
#  'Lung_Opacity',
#  'Viral Pneumonia',
#  'Normal',
#  'Lung_Opacity',
#  'Lung_Opacity',
#  'Lung_Opacity',
#  'Viral Pneumonia',
#  'Lung_Opacity',
#  'Viral Pneumonia',
#  'Lung_Opacity',
#  'Lung_Opacity',
#  'Normal',
#  'Lung_Opacity',
#  'Lung_Opacity',
#  'Lung_Opacity',
#  'Viral Pneumonia',
#  'Lung_Opacity',
#  'Viral Pneumonia',
#  'Lung_Opacity',
#  'Lung_Opacity',
#  'Normal',
#  'Lung_Opacity',
#  'Viral Pneumonia',
#  'Normal',
#  'Viral Pneumonia',
#  'Lung_Opacity',
#  'Lung_Opacity',
#  'Viral Pneumonia',
#  'Lung_Opacity',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Viral Pneumonia',
#  'Lung_Opacity',
#  'Lung_Opacity',
#  'Normal',
#  'Normal',
#  'Viral Pneumonia',
#  'Lung_Opacity',
#  'Normal',
#  'Viral Pneumonia',
#  'Normal',
#  'Lung_Opacity',
#  'Normal',
#  'Lung_Opacity',
#  'Normal',
#  'Lung_Opacity',
#  'Normal',
#  'Lung_Opacity',
#  'Normal',
#  'Normal',
#  'Lung_Opacity',
#  'Viral Pneumonia',
#  'Normal',
#  'Lung_Opacity',
#  'Normal',
#  'Normal',
#  'Lung_Opacity',
#  'Lung_Opacity',
#  'Lung_Opacity',
#  'Lung_Opacity',
#  'Normal',
#  'Lung_Opacity',
#  'Normal',
#  'Normal',
#  'Lung_Opacity',
#  'Lung_Opacity',
#  'Viral Pneumonia',
#  'Lung_Opacity',
#  'Lung_Opacity',
#  'Lung_Opacity',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Viral Pneumonia',
#  'Normal',
#  'Normal',
#  'Lung_Opacity',
#  'Viral Pneumonia',
#  'Lung_Opacity',
#  'Normal',
#  'Lung_Opacity',
#  'Normal',
#  'Lung_Opacity',
#  'Viral Pneumonia',
#  'Normal',
#  'Viral Pneumonia',
#  'Viral Pneumonia',
#  'Lung_Opacity',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Viral Pneumonia',
#  'Viral Pneumonia',
#  'Viral Pneumonia',
#  'Lung_Opacity',
#  'Normal',
#  'Normal',
#  'Lung_Opacity',
#  'Normal',
#  'Normal',
#  'Lung_Opacity',
#  'Normal',
#  'Normal',
#  'Viral Pneumonia',
#  'Lung_Opacity',
#  'Normal',
#  'Viral Pneumonia',
#  'Lung_Opacity',
#  'Normal',
#  'Viral Pneumonia',
#  'Normal',
#  'Viral Pneumonia',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Lung_Opacity',
#  'Viral Pneumonia',
#  'Lung_Opacity',
#  'Normal',
#  'Viral Pneumonia',
#  'Viral Pneumonia',
#  'Viral Pneumonia',
#  'Lung_Opacity',
#  'Normal',
#  'Lung_Opacity',
#  'Normal',
#  'Viral Pneumonia',
#  'Normal',
#  'Normal',
#  'Viral Pneumonia',
#  'Viral Pneumonia',
#  'Viral Pneumonia',
#  'Viral Pneumonia',
#  'Lung_Opacity',
#  'Lung_Opacity',
#  'Normal',
#  'Normal',
#  'Viral Pneumonia',
#  'Lung_Opacity',
#  'Normal',
#  'Normal',
#  'Normal',
#  'Viral Pneumonia',
#  'Viral Pneumonia',
#  'Lung_Opacity',
#  'Viral Pneumonia',
#  'Viral Pneumonia',
#  'Lung_Opacity',
#  'Normal',
#  'Viral Pneumonia',
#  'Lung_Opacity',
#  ...]

# %%
plt.figure(figsize=(20, 10))

random_indices = np.random.choice(len(test_generator), size=10, replace=False)

# Plot true labels and predicted labels side by side
for idx, i in enumerate(random_indices):
    plt.subplot(2, 5, idx + 1)
    plt.imshow(test_generator[i][0][0])  # Display the first image of the batch
    plt.title(f"True Class: {categories[true_value[i]]}\nPredicted Class: {pred_class_name[i]}")
    plt.axis('off')


plt.tight_layout()
plt.show()

# %%
print(confusion_matrix(true_value,pred))
# Out:
# [[391  12   2]
#  [ 10 440   0]
#  [  0   2 394]]
